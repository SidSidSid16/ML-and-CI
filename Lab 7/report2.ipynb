# %%
import argparse
from itertools import count
import os, sys, random
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Normal
from tensorboardX import SummaryWriter

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
import gym
env = gym.make('MountainCarContinuous-v0', render_mode="rgb_array")
directory = ''

# %%
random_seed = 10
torch.manual_seed(random_seed)
np.random.seed(random_seed)

state_dim = env.observation_space.shape[0]
action_dim = env.action_space.shape[0]
max_action = float(env.action_space.high[0])
min_Val = torch.tensor(1e-7).float().to(device) # min value
print(state_dim, action_dim, min_Val, max_action)
# Out:
# 2 1 tensor(1.0000e-07) 1.0

# %%
class Replay_buffer():
    '''
    Expects tuples of (state, next_state, action, reward, done)
    '''
    def __init__(self, max_size=100000):
        self.storage = []
        self.max_size = max_size
        self.ptr = 0

    def push(self, data):
        if len(self.storage) == self.max_size:
            self.storage[int(self.ptr)] = data
            self.ptr = (self.ptr + 1) % self.max_size
        else:
            self.storage.append(data)

    def sample(self, batch_size):
        ind = np.random.randint(0, len(self.storage), size=batch_size)
        x, y, u, r, d = [], [], [], [], []

        for i in ind:
            X, Y, U, R, D = self.storage[i]
            x.append(np.array(X, copy=False))
            y.append(np.array(Y, copy=False))
            u.append(np.array(U, copy=False))
            r.append(np.array(R, copy=False))
            d.append(np.array(D, copy=False))

        return np.array(x), np.array(y), np.array(u), np.array(r).reshape(-1, 1), np.array(d).reshape(-1, 1)

# %%
class Actor(nn.Module):
    def __init__(self, state_dim, action_dim, max_action):
        super(Actor, self).__init__()

        self.l1 = nn.Linear(state_dim, 400)
        self.l2 = nn.Linear(400, 300)
        self.l3 = nn.Linear(300, action_dim)

        self.max_action = max_action

    def forward(self, x):
        x = F.relu(self.l1(x))
        x = F.relu(self.l2(x))
        x = self.max_action * torch.tanh(self.l3(x))
        return x

# %%
class Critic(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(Critic, self).__init__()

        self.l1 = nn.Linear(state_dim + action_dim, 400)
        self.l2 = nn.Linear(400 , 300)
        self.l3 = nn.Linear(300, 1)

    def forward(self, x, u):
        x = F.relu(self.l1(torch.cat([x, u], 1)))
        x = F.relu(self.l2(x))
        x = self.l3(x)
        return x

# %%
class DDPG(object):
    def __init__(self, state_dim, action_dim, max_action):
        self.actor = Actor(state_dim, action_dim, max_action).to(device)
        self.actor_target = Actor(state_dim, action_dim, max_action).to(device)
        self.actor_target.load_state_dict(self.actor.state_dict())
        self.actor_optimizer = optim.Adam(self.actor.parameters(), lr=1e-4)

        self.critic = Critic(state_dim, action_dim).to(device)
        self.critic_target = Critic(state_dim, action_dim).to(device)
        self.critic_target.load_state_dict(self.critic.state_dict())
        self.critic_optimizer = optim.Adam(self.critic.parameters(), lr=1e-3)
        self.replay_buffer = Replay_buffer()
        self.writer = SummaryWriter(directory)

        self.num_critic_update_iteration = 0
        self.num_actor_update_iteration = 0
        self.num_training = 0
        self.update_iteration = 200
        self.tau = 0.005
        self.gamma = 0.99
        self.batch_size = 100

    def select_action(self, state):
        state = torch.FloatTensor(state.reshape(1, -1)).to(device)
        return self.actor(state).cpu().data.numpy().flatten()

    def update(self):

        for it in range(self.update_iteration):
            # Sample replay buffer
            x, y, u, r, d = self.replay_buffer.sample(self.batch_size)
            state = torch.FloatTensor(x).to(device)
            action = torch.FloatTensor(u).to(device)
            next_state = torch.FloatTensor(y).to(device)
            done = torch.FloatTensor(1-d).to(device)
            reward = torch.FloatTensor(r).to(device)

            # Compute the target Q value
            target_Q = self.critic_target(next_state, self.actor_target(next_state))
            target_Q = reward + (done * self.gamma * target_Q).detach()

            # Get current Q estimate
            current_Q = self.critic(state, action)

            # Compute critic loss
            critic_loss = F.mse_loss(current_Q, target_Q)
            self.writer.add_scalar('Loss/critic_loss', critic_loss, global_step=self.num_critic_update_iteration)
            # Optimize the critic
            self.critic_optimizer.zero_grad()
            critic_loss.backward()
            self.critic_optimizer.step()

            # Compute actor loss
            actor_loss = -self.critic(state, self.actor(state)).mean()
            self.writer.add_scalar('Loss/actor_loss', actor_loss, global_step=self.num_actor_update_iteration)

            # Optimize the actor
            self.actor_optimizer.zero_grad()
            actor_loss.backward()
            self.actor_optimizer.step()

            # Update the frozen target models
            for param, target_param in zip(self.critic.parameters(), self.critic_target.parameters()):
                target_param.data.copy_(self.tau * param.data + (1 - self.tau) * target_param.data)

            for param, target_param in zip(self.actor.parameters(), self.actor_target.parameters()):
                target_param.data.copy_(self.tau * param.data + (1 - self.tau) * target_param.data)

            self.num_actor_update_iteration += 1
            self.num_critic_update_iteration += 1

    def save(self):
        torch.save(self.actor.state_dict(), directory + 'actor.pth')
        torch.save(self.critic.state_dict(), directory + 'critic.pth')
        # print("====================================")
        # print("Model has been saved...")
        # print("====================================")

    def load(self):
        self.actor.load_state_dict(torch.load(directory + 'actor.pth'))
        self.critic.load_state_dict(torch.load(directory + 'critic.pth'))
        print("====================================")
        print("model has been loaded...")
        print("====================================")

# %%
agent = DDPG(state_dim, action_dim, max_action)
ep_r = 0

# %%
def train(max_episode = 500, log_interval=5, render=False, time_steps = 200, exploration_noise = 0.01):
    all_rewards = []
    for i in range(max_episode):
        total_reward = 0
        step =0
        total_step = 0
        state = env.reset()
        state = np.asarray(state[0])
        for t in range(time_steps):
            action = agent.select_action(state)
            # print(action)
            action = (action + np.random.normal(0, exploration_noise, size=env.action_space.shape[0])).clip(
                env.action_space.low, env.action_space.high)

            next_state, reward, done, info, _ = env.step(action)
            if render:
                env.render()
            agent.replay_buffer.push((state, next_state, action, reward, 0))

            state = next_state
            if done:
                break
            step += 1
            total_reward += reward
        total_step += step+1
        all_rewards.append(total_reward)
        print("Total T:{} Episode: \t{} Total Reward: \t{:0.2f}".format(total_step, i, total_reward))
        agent.update()

        if i % log_interval == 0:
            agent.save()
    return all_rewards

# %%
rewards = train()
# Out:
# Total T:201 Episode: 	0 Total Reward: 	-0.01
# /Users/sid/.pyenv/versions/3.11.2/envs/mlci-venv-3.11.2/lib/python3.11/site-packages/gym/utils/passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# Total T:201 Episode: 	1 Total Reward: 	-0.54
# Total T:201 Episode: 	2 Total Reward: 	-0.17
# Total T:201 Episode: 	3 Total Reward: 	-0.00
# Total T:201 Episode: 	4 Total Reward: 	-0.00
# Total T:201 Episode: 	5 Total Reward: 	-0.00
# Total T:201 Episode: 	6 Total Reward: 	-0.00
# Total T:201 Episode: 	7 Total Reward: 	-0.00
# Total T:201 Episode: 	8 Total Reward: 	-0.01
# Total T:201 Episode: 	9 Total Reward: 	-0.00
# Total T:201 Episode: 	10 Total Reward: 	-0.00
# Total T:201 Episode: 	11 Total Reward: 	-0.00
# Total T:201 Episode: 	12 Total Reward: 	-0.00
# Total T:201 Episode: 	13 Total Reward: 	-0.00
# Total T:201 Episode: 	14 Total Reward: 	-0.00
# Total T:201 Episode: 	15 Total Reward: 	-0.00
# Total T:201 Episode: 	16 Total Reward: 	-0.01
# Total T:201 Episode: 	17 Total Reward: 	-0.00
# Total T:201 Episode: 	18 Total Reward: 	-0.00
# Total T:201 Episode: 	19 Total Reward: 	-0.01
# Total T:201 Episode: 	20 Total Reward: 	-0.00
# Total T:201 Episode: 	21 Total Reward: 	-0.00
# Total T:201 Episode: 	22 Total Reward: 	-0.00
# Total T:201 Episode: 	23 Total Reward: 	-0.00
# Total T:201 Episode: 	24 Total Reward: 	-0.00
# Total T:201 Episode: 	25 Total Reward: 	-0.00
# Total T:201 Episode: 	26 Total Reward: 	-0.00
# Total T:201 Episode: 	27 Total Reward: 	-0.01
# Total T:201 Episode: 	28 Total Reward: 	-0.00
# Total T:201 Episode: 	29 Total Reward: 	-0.02
# Total T:201 Episode: 	30 Total Reward: 	-0.00
# Total T:201 Episode: 	31 Total Reward: 	-0.00
# Total T:201 Episode: 	32 Total Reward: 	-0.00
# Total T:201 Episode: 	33 Total Reward: 	-0.00
# Total T:201 Episode: 	34 Total Reward: 	-0.01
# Total T:201 Episode: 	35 Total Reward: 	-0.00
# Total T:201 Episode: 	36 Total Reward: 	-0.00
# Total T:201 Episode: 	37 Total Reward: 	-0.01
# Total T:201 Episode: 	38 Total Reward: 	-0.00
# Total T:201 Episode: 	39 Total Reward: 	-0.00
# Total T:201 Episode: 	40 Total Reward: 	-0.00
# Total T:201 Episode: 	41 Total Reward: 	-0.00
# Total T:201 Episode: 	42 Total Reward: 	-0.00
# Total T:201 Episode: 	43 Total Reward: 	-0.00
# Total T:201 Episode: 	44 Total Reward: 	-0.00
# Total T:201 Episode: 	45 Total Reward: 	-0.00
# Total T:201 Episode: 	46 Total Reward: 	-0.00
# Total T:201 Episode: 	47 Total Reward: 	-0.00
# Total T:201 Episode: 	48 Total Reward: 	-0.00
# Total T:201 Episode: 	49 Total Reward: 	-0.00
# Total T:201 Episode: 	50 Total Reward: 	-0.00
# Total T:201 Episode: 	51 Total Reward: 	-0.00
# Total T:201 Episode: 	52 Total Reward: 	-0.00
# Total T:201 Episode: 	53 Total Reward: 	-0.00
# Total T:201 Episode: 	54 Total Reward: 	-0.00
# Total T:201 Episode: 	55 Total Reward: 	-0.00
# Total T:201 Episode: 	56 Total Reward: 	-0.00
# Total T:201 Episode: 	57 Total Reward: 	-0.00
# Total T:201 Episode: 	58 Total Reward: 	-0.00
# Total T:201 Episode: 	59 Total Reward: 	-0.00
# Total T:201 Episode: 	60 Total Reward: 	-0.00
# Total T:201 Episode: 	61 Total Reward: 	-0.00
# Total T:201 Episode: 	62 Total Reward: 	-0.00
# Total T:201 Episode: 	63 Total Reward: 	-0.00
# Total T:201 Episode: 	64 Total Reward: 	-0.00
# Total T:201 Episode: 	65 Total Reward: 	-0.00
# Total T:201 Episode: 	66 Total Reward: 	-0.00
# Total T:201 Episode: 	67 Total Reward: 	-0.00
# Total T:201 Episode: 	68 Total Reward: 	-0.00
# Total T:201 Episode: 	69 Total Reward: 	-0.00
# Total T:201 Episode: 	70 Total Reward: 	-0.00
# Total T:201 Episode: 	71 Total Reward: 	-0.00
# Total T:201 Episode: 	72 Total Reward: 	-0.00
# Total T:201 Episode: 	73 Total Reward: 	-0.00
# Total T:201 Episode: 	74 Total Reward: 	-0.00
# Total T:201 Episode: 	75 Total Reward: 	-0.00
# Total T:201 Episode: 	76 Total Reward: 	-0.00
# Total T:201 Episode: 	77 Total Reward: 	-0.00
# Total T:201 Episode: 	78 Total Reward: 	-0.00
# Total T:201 Episode: 	79 Total Reward: 	-0.00
# Total T:201 Episode: 	80 Total Reward: 	-0.00
# Total T:201 Episode: 	81 Total Reward: 	-0.00
# Total T:201 Episode: 	82 Total Reward: 	-0.00
# Total T:201 Episode: 	83 Total Reward: 	-0.00
# Total T:201 Episode: 	84 Total Reward: 	-0.00
# Total T:201 Episode: 	85 Total Reward: 	-0.00
# Total T:201 Episode: 	86 Total Reward: 	-0.00
# Total T:201 Episode: 	87 Total Reward: 	-0.00
# Total T:201 Episode: 	88 Total Reward: 	-0.00
# Total T:201 Episode: 	89 Total Reward: 	-0.00
# Total T:201 Episode: 	90 Total Reward: 	-0.00
# Total T:201 Episode: 	91 Total Reward: 	-0.00
# Total T:201 Episode: 	92 Total Reward: 	-0.00
# Total T:201 Episode: 	93 Total Reward: 	-0.00
# Total T:201 Episode: 	94 Total Reward: 	-0.00
# Total T:201 Episode: 	95 Total Reward: 	-0.00
# Total T:201 Episode: 	96 Total Reward: 	-0.00
# Total T:201 Episode: 	97 Total Reward: 	-0.00
# Total T:201 Episode: 	98 Total Reward: 	-0.00
# Total T:201 Episode: 	99 Total Reward: 	-0.00
# Total T:201 Episode: 	100 Total Reward: 	-0.00
# Total T:201 Episode: 	101 Total Reward: 	-0.00
# Total T:201 Episode: 	102 Total Reward: 	-0.00
# Total T:201 Episode: 	103 Total Reward: 	-0.00
# Total T:201 Episode: 	104 Total Reward: 	-0.00
# Total T:201 Episode: 	105 Total Reward: 	-0.00
# Total T:201 Episode: 	106 Total Reward: 	-0.00
# Total T:201 Episode: 	107 Total Reward: 	-0.00
# Total T:201 Episode: 	108 Total Reward: 	-0.00
# Total T:201 Episode: 	109 Total Reward: 	-0.00
# Total T:201 Episode: 	110 Total Reward: 	-0.00
# Total T:201 Episode: 	111 Total Reward: 	-0.00
# Total T:201 Episode: 	112 Total Reward: 	-0.00
# Total T:201 Episode: 	113 Total Reward: 	-0.00
# Total T:201 Episode: 	114 Total Reward: 	-0.00
# Total T:201 Episode: 	115 Total Reward: 	-0.00
# Total T:201 Episode: 	116 Total Reward: 	-0.00
# Total T:201 Episode: 	117 Total Reward: 	-0.00
# Total T:201 Episode: 	118 Total Reward: 	-0.00
# Total T:201 Episode: 	119 Total Reward: 	-0.00
# Total T:201 Episode: 	120 Total Reward: 	-0.00
# Total T:201 Episode: 	121 Total Reward: 	-0.00
# Total T:201 Episode: 	122 Total Reward: 	-0.00
# Total T:201 Episode: 	123 Total Reward: 	-0.00
# Total T:201 Episode: 	124 Total Reward: 	-0.00
# Total T:201 Episode: 	125 Total Reward: 	-0.00
# Total T:201 Episode: 	126 Total Reward: 	-0.00
# Total T:201 Episode: 	127 Total Reward: 	-0.00
# Total T:201 Episode: 	128 Total Reward: 	-0.00
# Total T:201 Episode: 	129 Total Reward: 	-0.00
# Total T:201 Episode: 	130 Total Reward: 	-0.01
# Total T:201 Episode: 	131 Total Reward: 	-0.00
# Total T:201 Episode: 	132 Total Reward: 	-0.00
# Total T:201 Episode: 	133 Total Reward: 	-0.00
# Total T:201 Episode: 	134 Total Reward: 	-0.00
# Total T:201 Episode: 	135 Total Reward: 	-0.00
# Total T:201 Episode: 	136 Total Reward: 	-0.00
# Total T:201 Episode: 	137 Total Reward: 	-0.00
# Total T:201 Episode: 	138 Total Reward: 	-0.00
# Total T:201 Episode: 	139 Total Reward: 	-0.00
# Total T:201 Episode: 	140 Total Reward: 	-0.00
# Total T:201 Episode: 	141 Total Reward: 	-0.00
# Total T:201 Episode: 	142 Total Reward: 	-0.00
# Total T:201 Episode: 	143 Total Reward: 	-0.00
# Total T:201 Episode: 	144 Total Reward: 	-0.00
# Total T:201 Episode: 	145 Total Reward: 	-0.00
# Total T:201 Episode: 	146 Total Reward: 	-0.00
# Total T:201 Episode: 	147 Total Reward: 	-0.00
# Total T:201 Episode: 	148 Total Reward: 	-0.00
# Total T:201 Episode: 	149 Total Reward: 	-0.00
# Total T:201 Episode: 	150 Total Reward: 	-0.00
# Total T:201 Episode: 	151 Total Reward: 	-0.00
# Total T:201 Episode: 	152 Total Reward: 	-0.00
# Total T:201 Episode: 	153 Total Reward: 	-0.00
# Total T:201 Episode: 	154 Total Reward: 	-0.00
# Total T:201 Episode: 	155 Total Reward: 	-0.00
# Total T:201 Episode: 	156 Total Reward: 	-0.00
# Total T:201 Episode: 	157 Total Reward: 	-0.00
# Total T:201 Episode: 	158 Total Reward: 	-0.00
# Total T:201 Episode: 	159 Total Reward: 	-0.00
# Total T:201 Episode: 	160 Total Reward: 	-0.00
# Total T:201 Episode: 	161 Total Reward: 	-0.00
# Total T:201 Episode: 	162 Total Reward: 	-0.00
# Total T:201 Episode: 	163 Total Reward: 	-0.00
# Total T:201 Episode: 	164 Total Reward: 	-0.00
# Total T:201 Episode: 	165 Total Reward: 	-0.00
# Total T:201 Episode: 	166 Total Reward: 	-0.00
# Total T:201 Episode: 	167 Total Reward: 	-0.00
# Total T:201 Episode: 	168 Total Reward: 	-0.00
# Total T:201 Episode: 	169 Total Reward: 	-0.00
# Total T:201 Episode: 	170 Total Reward: 	-0.00
# Total T:201 Episode: 	171 Total Reward: 	-0.00
# Total T:201 Episode: 	172 Total Reward: 	-0.00
# Total T:201 Episode: 	173 Total Reward: 	-0.00
# Total T:201 Episode: 	174 Total Reward: 	-0.00
# Total T:201 Episode: 	175 Total Reward: 	-0.00
# Total T:201 Episode: 	176 Total Reward: 	-0.00
# Total T:201 Episode: 	177 Total Reward: 	-0.00
# Total T:201 Episode: 	178 Total Reward: 	-0.00
# Total T:201 Episode: 	179 Total Reward: 	-0.00
# Total T:201 Episode: 	180 Total Reward: 	-0.00
# Total T:201 Episode: 	181 Total Reward: 	-0.00
# Total T:201 Episode: 	182 Total Reward: 	-0.00
# Total T:201 Episode: 	183 Total Reward: 	-0.00
# Total T:201 Episode: 	184 Total Reward: 	-0.00
# Total T:201 Episode: 	185 Total Reward: 	-0.00
# Total T:201 Episode: 	186 Total Reward: 	-0.00
# Total T:201 Episode: 	187 Total Reward: 	-0.00
# Total T:201 Episode: 	188 Total Reward: 	-0.00
# Total T:201 Episode: 	189 Total Reward: 	-0.00
# Total T:201 Episode: 	190 Total Reward: 	-0.00
# Total T:201 Episode: 	191 Total Reward: 	-0.00
# Total T:201 Episode: 	192 Total Reward: 	-0.00
# Total T:201 Episode: 	193 Total Reward: 	-0.00
# Total T:201 Episode: 	194 Total Reward: 	-0.00
# Total T:201 Episode: 	195 Total Reward: 	-0.00
# Total T:201 Episode: 	196 Total Reward: 	-0.00
# Total T:201 Episode: 	197 Total Reward: 	-0.00
# Total T:201 Episode: 	198 Total Reward: 	-0.00
# Total T:201 Episode: 	199 Total Reward: 	-0.00
# Total T:201 Episode: 	200 Total Reward: 	-0.00
# Total T:201 Episode: 	201 Total Reward: 	-0.00
# Total T:201 Episode: 	202 Total Reward: 	-0.00
# Total T:201 Episode: 	203 Total Reward: 	-0.00
# Total T:201 Episode: 	204 Total Reward: 	-0.00
# Total T:201 Episode: 	205 Total Reward: 	-0.00
# Total T:201 Episode: 	206 Total Reward: 	-0.00
# Total T:201 Episode: 	207 Total Reward: 	-0.00
# Total T:201 Episode: 	208 Total Reward: 	-0.00
# Total T:201 Episode: 	209 Total Reward: 	-0.00
# Total T:201 Episode: 	210 Total Reward: 	-0.00
# Total T:201 Episode: 	211 Total Reward: 	-0.00
# Total T:201 Episode: 	212 Total Reward: 	-0.00
# Total T:201 Episode: 	213 Total Reward: 	-0.00
# Total T:201 Episode: 	214 Total Reward: 	-0.00
# Total T:201 Episode: 	215 Total Reward: 	-0.00
# Total T:201 Episode: 	216 Total Reward: 	-0.00
# Total T:201 Episode: 	217 Total Reward: 	-0.00
# Total T:201 Episode: 	218 Total Reward: 	-0.00
# Total T:201 Episode: 	219 Total Reward: 	-0.00
# Total T:201 Episode: 	220 Total Reward: 	-0.00
# Total T:201 Episode: 	221 Total Reward: 	-0.00
# Total T:201 Episode: 	222 Total Reward: 	-0.00
# Total T:201 Episode: 	223 Total Reward: 	-0.00
# Total T:201 Episode: 	224 Total Reward: 	-0.00
# Total T:201 Episode: 	225 Total Reward: 	-0.00
# Total T:201 Episode: 	226 Total Reward: 	-0.00
# Total T:201 Episode: 	227 Total Reward: 	-0.00
# Total T:201 Episode: 	228 Total Reward: 	-0.00
# Total T:201 Episode: 	229 Total Reward: 	-0.00
# Total T:201 Episode: 	230 Total Reward: 	-0.00
# Total T:201 Episode: 	231 Total Reward: 	-0.00
# Total T:201 Episode: 	232 Total Reward: 	-0.00
# Total T:201 Episode: 	233 Total Reward: 	-0.00
# Total T:201 Episode: 	234 Total Reward: 	-0.00
# Total T:201 Episode: 	235 Total Reward: 	-0.00
# Total T:201 Episode: 	236 Total Reward: 	-0.00
# Total T:201 Episode: 	237 Total Reward: 	-0.00
# Total T:201 Episode: 	238 Total Reward: 	-0.00
# Total T:201 Episode: 	239 Total Reward: 	-0.00
# Total T:201 Episode: 	240 Total Reward: 	-0.54
# Total T:201 Episode: 	241 Total Reward: 	-0.02
# Total T:201 Episode: 	242 Total Reward: 	-0.02
# Total T:201 Episode: 	243 Total Reward: 	-0.23
# Total T:201 Episode: 	244 Total Reward: 	-0.38
# Total T:201 Episode: 	245 Total Reward: 	-0.36
# Total T:201 Episode: 	246 Total Reward: 	-0.37
# Total T:201 Episode: 	247 Total Reward: 	-0.36
# Total T:201 Episode: 	248 Total Reward: 	-0.37
# Total T:201 Episode: 	249 Total Reward: 	-0.38
# Total T:201 Episode: 	250 Total Reward: 	-0.37
# Total T:201 Episode: 	251 Total Reward: 	-0.37
# Total T:201 Episode: 	252 Total Reward: 	-0.37
# Total T:201 Episode: 	253 Total Reward: 	-0.37
# Total T:201 Episode: 	254 Total Reward: 	-0.37
# Total T:201 Episode: 	255 Total Reward: 	-0.36
# Total T:201 Episode: 	256 Total Reward: 	-0.37
# Total T:201 Episode: 	257 Total Reward: 	-0.37
# Total T:201 Episode: 	258 Total Reward: 	-0.37
# Total T:201 Episode: 	259 Total Reward: 	-0.37
# Total T:201 Episode: 	260 Total Reward: 	-0.38
# Total T:201 Episode: 	261 Total Reward: 	-0.37
# Total T:201 Episode: 	262 Total Reward: 	-0.37
# Total T:201 Episode: 	263 Total Reward: 	-0.37
# Total T:201 Episode: 	264 Total Reward: 	-0.36
# Total T:201 Episode: 	265 Total Reward: 	-0.36
# Total T:201 Episode: 	266 Total Reward: 	-0.38
# Total T:201 Episode: 	267 Total Reward: 	-0.38
# Total T:201 Episode: 	268 Total Reward: 	-0.37
# Total T:201 Episode: 	269 Total Reward: 	-0.36
# Total T:201 Episode: 	270 Total Reward: 	-0.37
# Total T:201 Episode: 	271 Total Reward: 	-0.37
# Total T:201 Episode: 	272 Total Reward: 	-0.38
# Total T:201 Episode: 	273 Total Reward: 	-0.36
# Total T:201 Episode: 	274 Total Reward: 	-0.37
# Total T:201 Episode: 	275 Total Reward: 	-0.38
# Total T:201 Episode: 	276 Total Reward: 	-0.37
# Total T:201 Episode: 	277 Total Reward: 	-0.38
# Total T:201 Episode: 	278 Total Reward: 	-0.37
# Total T:201 Episode: 	279 Total Reward: 	-0.38
# Total T:201 Episode: 	280 Total Reward: 	-0.37
# Total T:201 Episode: 	281 Total Reward: 	-0.37
# Total T:201 Episode: 	282 Total Reward: 	-0.37
# Total T:201 Episode: 	283 Total Reward: 	-0.37
# Total T:201 Episode: 	284 Total Reward: 	-0.37
# Total T:201 Episode: 	285 Total Reward: 	-0.38
# Total T:201 Episode: 	286 Total Reward: 	-0.37
# Total T:201 Episode: 	287 Total Reward: 	-0.36
# Total T:201 Episode: 	288 Total Reward: 	-0.38
# Total T:201 Episode: 	289 Total Reward: 	-0.37
# Total T:201 Episode: 	290 Total Reward: 	-0.37
# Total T:201 Episode: 	291 Total Reward: 	-0.37
# Total T:201 Episode: 	292 Total Reward: 	-0.36
# Total T:201 Episode: 	293 Total Reward: 	-0.36
# Total T:201 Episode: 	294 Total Reward: 	-0.37
# Total T:201 Episode: 	295 Total Reward: 	-0.37
# Total T:201 Episode: 	296 Total Reward: 	-0.37
# Total T:201 Episode: 	297 Total Reward: 	-0.38
# Total T:201 Episode: 	298 Total Reward: 	-0.37
# Total T:201 Episode: 	299 Total Reward: 	-0.37
# Total T:201 Episode: 	300 Total Reward: 	-0.37
# Total T:201 Episode: 	301 Total Reward: 	-0.37
# Total T:201 Episode: 	302 Total Reward: 	-0.36
# Total T:201 Episode: 	303 Total Reward: 	-0.37
# Total T:201 Episode: 	304 Total Reward: 	-0.36
# Total T:201 Episode: 	305 Total Reward: 	-0.37
# Total T:201 Episode: 	306 Total Reward: 	-0.37
# Total T:201 Episode: 	307 Total Reward: 	-0.37
# Total T:201 Episode: 	308 Total Reward: 	-0.37
# Total T:201 Episode: 	309 Total Reward: 	-0.37
# Total T:201 Episode: 	310 Total Reward: 	-0.37
# Total T:201 Episode: 	311 Total Reward: 	-0.38
# Total T:201 Episode: 	312 Total Reward: 	-0.37
# Total T:201 Episode: 	313 Total Reward: 	-0.36
# Total T:201 Episode: 	314 Total Reward: 	-0.38
# Total T:201 Episode: 	315 Total Reward: 	-0.36
# Total T:201 Episode: 	316 Total Reward: 	-0.37
# Total T:201 Episode: 	317 Total Reward: 	-0.37
# Total T:201 Episode: 	318 Total Reward: 	-0.37
# Total T:201 Episode: 	319 Total Reward: 	-0.37
# Total T:201 Episode: 	320 Total Reward: 	-0.37
# Total T:201 Episode: 	321 Total Reward: 	-0.36
# Total T:201 Episode: 	322 Total Reward: 	-0.37
# Total T:201 Episode: 	323 Total Reward: 	-0.37
# Total T:201 Episode: 	324 Total Reward: 	-0.38
# Total T:201 Episode: 	325 Total Reward: 	-0.37
# Total T:201 Episode: 	326 Total Reward: 	-0.36
# Total T:201 Episode: 	327 Total Reward: 	-0.38
# Total T:201 Episode: 	328 Total Reward: 	-0.37
# Total T:201 Episode: 	329 Total Reward: 	-0.37
# Total T:201 Episode: 	330 Total Reward: 	-0.37
# Total T:201 Episode: 	331 Total Reward: 	-0.37
# Total T:201 Episode: 	332 Total Reward: 	-0.36
# Total T:201 Episode: 	333 Total Reward: 	-0.38
# Total T:201 Episode: 	334 Total Reward: 	-0.37
# Total T:201 Episode: 	335 Total Reward: 	-0.37
# Total T:201 Episode: 	336 Total Reward: 	-0.37
# Total T:201 Episode: 	337 Total Reward: 	-0.37
# Total T:201 Episode: 	338 Total Reward: 	-0.37
# Total T:201 Episode: 	339 Total Reward: 	-0.37
# Total T:201 Episode: 	340 Total Reward: 	-0.38
# Total T:201 Episode: 	341 Total Reward: 	-0.36
# Total T:201 Episode: 	342 Total Reward: 	-0.37
# Total T:201 Episode: 	343 Total Reward: 	-0.37
# Total T:201 Episode: 	344 Total Reward: 	-0.37
# Total T:201 Episode: 	345 Total Reward: 	-0.38
# Total T:201 Episode: 	346 Total Reward: 	-0.37
# Total T:201 Episode: 	347 Total Reward: 	-0.37
# Total T:201 Episode: 	348 Total Reward: 	-0.37
# Total T:201 Episode: 	349 Total Reward: 	-0.37
# Total T:201 Episode: 	350 Total Reward: 	-0.37
# Total T:201 Episode: 	351 Total Reward: 	-0.36
# Total T:201 Episode: 	352 Total Reward: 	-0.37
# Total T:201 Episode: 	353 Total Reward: 	-0.38
# Total T:201 Episode: 	354 Total Reward: 	-0.38
# Total T:201 Episode: 	355 Total Reward: 	-0.37
# Total T:201 Episode: 	356 Total Reward: 	-0.37
# Total T:201 Episode: 	357 Total Reward: 	-0.37
# Total T:201 Episode: 	358 Total Reward: 	-0.36
# Total T:201 Episode: 	359 Total Reward: 	-0.38
# Total T:201 Episode: 	360 Total Reward: 	-0.37
# Total T:201 Episode: 	361 Total Reward: 	-0.37
# Total T:201 Episode: 	362 Total Reward: 	-0.37
# Total T:201 Episode: 	363 Total Reward: 	-0.37
# Total T:201 Episode: 	364 Total Reward: 	-0.36
# Total T:201 Episode: 	365 Total Reward: 	-0.37
# Total T:201 Episode: 	366 Total Reward: 	-0.36
# Total T:201 Episode: 	367 Total Reward: 	-0.38
# Total T:201 Episode: 	368 Total Reward: 	-0.37
# Total T:201 Episode: 	369 Total Reward: 	-0.37
# Total T:201 Episode: 	370 Total Reward: 	-0.37
# Total T:201 Episode: 	371 Total Reward: 	-0.37
# Total T:201 Episode: 	372 Total Reward: 	-0.36
# Total T:201 Episode: 	373 Total Reward: 	-0.38
# Total T:201 Episode: 	374 Total Reward: 	-0.37
# Total T:201 Episode: 	375 Total Reward: 	-0.37
# Total T:201 Episode: 	376 Total Reward: 	-0.37
# Total T:201 Episode: 	377 Total Reward: 	-0.38
# Total T:201 Episode: 	378 Total Reward: 	-0.36
# Total T:201 Episode: 	379 Total Reward: 	-0.07
# Total T:201 Episode: 	380 Total Reward: 	-0.04
# Total T:201 Episode: 	381 Total Reward: 	-0.03
# Total T:201 Episode: 	382 Total Reward: 	-0.04
# Total T:201 Episode: 	383 Total Reward: 	-0.03
# Total T:201 Episode: 	384 Total Reward: 	-0.03
# Total T:201 Episode: 	385 Total Reward: 	-0.03
# Total T:201 Episode: 	386 Total Reward: 	-0.04
# Total T:201 Episode: 	387 Total Reward: 	-0.03
# Total T:201 Episode: 	388 Total Reward: 	-0.03
# Total T:201 Episode: 	389 Total Reward: 	-0.03
# Total T:201 Episode: 	390 Total Reward: 	-0.04
# Total T:201 Episode: 	391 Total Reward: 	-0.04
# Total T:201 Episode: 	392 Total Reward: 	-0.03
# Total T:201 Episode: 	393 Total Reward: 	-0.03
# Total T:201 Episode: 	394 Total Reward: 	-0.04
# Total T:201 Episode: 	395 Total Reward: 	-0.03
# Total T:201 Episode: 	396 Total Reward: 	-0.04
# Total T:201 Episode: 	397 Total Reward: 	-0.04
# Total T:201 Episode: 	398 Total Reward: 	-0.03
# Total T:201 Episode: 	399 Total Reward: 	-0.04
# Total T:201 Episode: 	400 Total Reward: 	-0.01
# Total T:201 Episode: 	401 Total Reward: 	-0.01
# Total T:201 Episode: 	402 Total Reward: 	-0.01
# Total T:201 Episode: 	403 Total Reward: 	-0.01
# Total T:201 Episode: 	404 Total Reward: 	-0.01
# Total T:201 Episode: 	405 Total Reward: 	-0.01
# Total T:201 Episode: 	406 Total Reward: 	-0.01
# Total T:201 Episode: 	407 Total Reward: 	-0.01
# Total T:201 Episode: 	408 Total Reward: 	-0.01
# Total T:201 Episode: 	409 Total Reward: 	-0.01
# Total T:201 Episode: 	410 Total Reward: 	-0.01
# Total T:201 Episode: 	411 Total Reward: 	-0.01
# Total T:201 Episode: 	412 Total Reward: 	-0.01
# Total T:201 Episode: 	413 Total Reward: 	-0.01
# Total T:201 Episode: 	414 Total Reward: 	-0.01
# Total T:201 Episode: 	415 Total Reward: 	-0.01
# Total T:201 Episode: 	416 Total Reward: 	-0.01
# Total T:201 Episode: 	417 Total Reward: 	-0.01
# Total T:201 Episode: 	418 Total Reward: 	-0.01
# Total T:201 Episode: 	419 Total Reward: 	-0.01
# Total T:201 Episode: 	420 Total Reward: 	-0.01
# Total T:201 Episode: 	421 Total Reward: 	-0.01
# Total T:201 Episode: 	422 Total Reward: 	-0.01
# Total T:201 Episode: 	423 Total Reward: 	-0.01
# Total T:201 Episode: 	424 Total Reward: 	-0.01
# Total T:201 Episode: 	425 Total Reward: 	-0.01
# Total T:201 Episode: 	426 Total Reward: 	-0.01
# Total T:201 Episode: 	427 Total Reward: 	-0.01
# Total T:201 Episode: 	428 Total Reward: 	-0.01
# Total T:201 Episode: 	429 Total Reward: 	-0.01
# Total T:201 Episode: 	430 Total Reward: 	-0.01
# Total T:201 Episode: 	431 Total Reward: 	-0.01
# Total T:201 Episode: 	432 Total Reward: 	-0.01
# Total T:201 Episode: 	433 Total Reward: 	-0.01
# Total T:201 Episode: 	434 Total Reward: 	-0.01
# Total T:201 Episode: 	435 Total Reward: 	-0.01
# Total T:201 Episode: 	436 Total Reward: 	-0.01
# Total T:201 Episode: 	437 Total Reward: 	-0.01
# Total T:201 Episode: 	438 Total Reward: 	-0.01
# Total T:201 Episode: 	439 Total Reward: 	-0.01
# Total T:201 Episode: 	440 Total Reward: 	-0.01
# Total T:201 Episode: 	441 Total Reward: 	-0.01
# Total T:201 Episode: 	442 Total Reward: 	-0.01
# Total T:201 Episode: 	443 Total Reward: 	-0.01
# Total T:201 Episode: 	444 Total Reward: 	-0.01
# Total T:201 Episode: 	445 Total Reward: 	-0.01
# Total T:201 Episode: 	446 Total Reward: 	-0.01
# Total T:201 Episode: 	447 Total Reward: 	-0.01
# Total T:201 Episode: 	448 Total Reward: 	-0.01
# Total T:201 Episode: 	449 Total Reward: 	-0.01
# Total T:201 Episode: 	450 Total Reward: 	-0.12
# Total T:201 Episode: 	451 Total Reward: 	-0.13
# Total T:201 Episode: 	452 Total Reward: 	-0.13
# Total T:201 Episode: 	453 Total Reward: 	-0.13
# Total T:201 Episode: 	454 Total Reward: 	-0.12
# Total T:201 Episode: 	455 Total Reward: 	-0.12
# Total T:201 Episode: 	456 Total Reward: 	-0.12
# Total T:201 Episode: 	457 Total Reward: 	-0.12
# Total T:201 Episode: 	458 Total Reward: 	-0.11
# Total T:201 Episode: 	459 Total Reward: 	-0.11
# Total T:201 Episode: 	460 Total Reward: 	-0.11
# Total T:201 Episode: 	461 Total Reward: 	-0.11
# Total T:201 Episode: 	462 Total Reward: 	-0.10
# Total T:201 Episode: 	463 Total Reward: 	-0.11
# Total T:201 Episode: 	464 Total Reward: 	-0.10
# Total T:201 Episode: 	465 Total Reward: 	-0.10
# Total T:201 Episode: 	466 Total Reward: 	-0.10
# Total T:201 Episode: 	467 Total Reward: 	-0.10
# Total T:201 Episode: 	468 Total Reward: 	-0.10
# Total T:201 Episode: 	469 Total Reward: 	-0.09
# Total T:201 Episode: 	470 Total Reward: 	-0.10
# Total T:201 Episode: 	471 Total Reward: 	-0.10
# Total T:201 Episode: 	472 Total Reward: 	-0.09
# Total T:201 Episode: 	473 Total Reward: 	-0.09
# Total T:201 Episode: 	474 Total Reward: 	-0.10
# Total T:201 Episode: 	475 Total Reward: 	-0.09
# Total T:201 Episode: 	476 Total Reward: 	-0.09
# Total T:201 Episode: 	477 Total Reward: 	-0.09
# Total T:201 Episode: 	478 Total Reward: 	-0.26
# Total T:201 Episode: 	479 Total Reward: 	-0.25
# Total T:201 Episode: 	480 Total Reward: 	-0.01
# Total T:201 Episode: 	481 Total Reward: 	-0.00
# Total T:201 Episode: 	482 Total Reward: 	-0.00
# Total T:201 Episode: 	483 Total Reward: 	-0.00
# Total T:201 Episode: 	484 Total Reward: 	-0.00
# Total T:201 Episode: 	485 Total Reward: 	-0.00
# Total T:201 Episode: 	486 Total Reward: 	-0.00
# Total T:201 Episode: 	487 Total Reward: 	-0.00
# Total T:201 Episode: 	488 Total Reward: 	-0.00
# Total T:201 Episode: 	489 Total Reward: 	-0.00
# Total T:201 Episode: 	490 Total Reward: 	-0.00
# Total T:201 Episode: 	491 Total Reward: 	-0.00
# Total T:201 Episode: 	492 Total Reward: 	-0.00
# Total T:201 Episode: 	493 Total Reward: 	-0.00
# Total T:201 Episode: 	494 Total Reward: 	-0.00
# Total T:201 Episode: 	495 Total Reward: 	-0.00
# Total T:201 Episode: 	496 Total Reward: 	-0.00
# Total T:201 Episode: 	497 Total Reward: 	-0.00
# Total T:201 Episode: 	498 Total Reward: 	-0.00
# Total T:201 Episode: 	499 Total Reward: 	-0.00

# %%
import matplotlib.pyplot as plt

episodes = [i for i in range(len(rewards))]
plt.plot(episodes, rewards)
plt.show()

# %%
def test(test_iteration=10, max_length_of_trajectory=100):
    ep_r = 0
    agent.load()
    for i in range(test_iteration):
        state = env.reset()
        state = np.asarray(state[0])
        for t in count():
            action = agent.select_action(state)
            # print(action)
            next_state, reward, done, info, _ = env.step(action)
            ep_r += reward
            env.render()
            if done or t >= max_length_of_trajectory:
                print("Ep_i \t{}, the ep_r is \t{:0.2f}, the step is \t{}".format(i, ep_r, t))
                ep_r = 0
                break
            state = next_state

# %%
test()
# Out:
# ====================================
# model has been loaded...
# ====================================
# Ep_i 	0, the ep_r is 	-0.00, the step is 	100
# Ep_i 	1, the ep_r is 	-0.00, the step is 	100
# Ep_i 	2, the ep_r is 	-0.00, the step is 	100
# Ep_i 	3, the ep_r is 	-0.00, the step is 	100
# Ep_i 	4, the ep_r is 	-0.00, the step is 	100
# Ep_i 	5, the ep_r is 	-0.00, the step is 	100
# Ep_i 	6, the ep_r is 	-0.00, the step is 	100
# Ep_i 	7, the ep_r is 	-0.00, the step is 	100
# Ep_i 	8, the ep_r is 	-0.00, the step is 	100
# Ep_i 	9, the ep_r is 	-0.00, the step is 	100
